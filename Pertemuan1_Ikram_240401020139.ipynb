# %% [markdown]
# # TUGAS PERTEMUAN 1 DATA SCIENCE
# * **Nama Lengkap:** IKRAM
# * **NIM:** 240401020139
# * **Kelas:** IF 405

# %%
print("Hallo, Data Science!")
# Out:
# Hallo, Data SCience!

# %%
nama = "Ikram"
angkatan = 2024
print(f"Hallo, nama saya {nama}, saya angkatan {angkatan}")
# Out:
# Hallo, nama saya Ikram, saya angkatan 2024

# %%
tools = ["Python","Colab","Jupyter","Github"]
for i, tool in enumerate(tools, 1):
  print(f"{i}. {tool}")
# Out:
# 1. Python
# 2. Colab
# 3. Jupyter
# 4. Github

# %%
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Ikram","Informatika",2024))
# Out:
# Ikram | Informatika | 2024

# %% [markdown]
# ### 📋 Kesimpulan Pertemuan 1
#
# * **Apa yang dipelajari:**
#   Dasar-dasar Data Science sebagai bidang multidisiplin, 6 fase siklus proyek data berbasis kerangka CRISP-DM, peran profesi data, serta dasar pemrograman Python di Google Colab.
#
# * **Temuan utama:**
#   * Fase *Business Understanding* adalah kunci utama kesuksesan proyek agar model analitik menjawab kebutuhan bisnis secara nyata.
#   * Fase *Data Preparation* (pembersihan data) merupakan tahap yang paling menyita waktu, yaitu sekitar 60–80% dari total proyek.
#   * Dasar Python seperti variabel, *list*, *for loop*, dan fungsi kustom (`def`) berhasil dijalankan dengan baik secara interaktif di Google Colab.
#
# * **Keterbatasan / Pertanyaan yang muncul:**
#   Bagaimana cara terbaik bagi pemula untuk menyeimbangkan penguasaan kemampuan teknis koding dengan pemahaman konteks bisnis (*domain knowledge*) di industri nyata?
